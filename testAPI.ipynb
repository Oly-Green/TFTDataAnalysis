# %%
import json
import requests

# %%
with open('keys.json') as f:
  keysRAW = f.read()
keys = json.loads(keysRAW)

# %%
api_url = "https://na1.api.riotgames.com"
grandmasterLeagueEnd = "/tft/league/v1/grandmaster"
response = requests.get(f"{api_url}{grandmasterLeagueEnd}", headers={"X-Riot-Token": keys["private"]})
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'tier': 'GRANDMASTER',
#  'leagueId': '19edec7a-a457-36a3-897d-a2f68b4c42a4',
#  'queue': 'RANKED_TFT',
#  'name': "Irelia's Weaponmasters",
#  'entries': [{'summonerId': 'HfRxRMrJ6dC7aAAvd6H4cnwwlALVEf3VTbSAXsUCkY9J6oMQ',
#    'summonerName': 'Bruhbruhbruh WHO',
#    'leaguePoints': 545,
#    'rank': 'I',
#    'wins': 284,
#    'losses': 258,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'XUDPbES2nAJgKNo9CzKOINHtiTmEcZi-UKqlY_KA1LvJ1RhK5j4YXRN_8g',
#    'summonerName': 'JonLearns',
#    'leaguePoints': 722,
#    'rank': 'I',
#    'wins': 145,
#    'losses': 103,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-2XkqY4bzWF3gFzq0TRUbs3nAa9Lrug-4-fB2G7ShCCigZIwCDPYB4MCGw',
#    'summonerName': 'Hao Yun DD',
#    'leaguePoints': 779,
#    'rank': 'I',
#    'wins': 493,
#    'losses': 452,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'USZUXzPtzJvAvo3Z1wL231Jij0nKM9rAuPbzDW5Y9JcMbcs',
#    'summonerName': 'The Nimble Niga',
#    'leaguePoints': 620,
#    'rank': 'I',
#    'wins': 226,
#    'losses': 174,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'dNBWoAyDPIIbbjon2UqJRJ_G9mOs9-NRv4GIO9UBTIvGf8Aa',
#    'summonerName': '1998HondaAccord',
#    'leaguePoints': 600,
#    'rank': 'I',
#    'wins': 250,
#    'losses': 204,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'AIyXK7UEMh8_ZtkGP136HJarA2jVUMbjTcnu_ja6lob1I-9E',
#    'summonerName': 'kaedenec',
#    'leaguePoints': 567,
#    'rank': 'I',
#    'wins': 244,
#    'losses': 217,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'VGw_GUjjThGi2Q6aB5cbXWVxVcTltSmiN1XDfRTIg1OFzIY',
#    'summonerName': 'Voltzwagon',
#    'leaguePoints': 719,
#    'rank': 'I',
#    'wins': 271,
#    'losses': 227,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'm-G4-xokEK7HDjkJIHKAFzxr12GBolXMGJHfFv3iK9t84D49otZ-rSTTLw',
#    'summonerName': 'jamjamminjam',
#    'leaguePoints': 526,
#    'rank': 'I',
#    'wins': 126,
#    'losses': 91,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'OzRspm8h9yfEeOm1K-37sEhL54suVAj4wgSUGXYJK5xMYgNq',
#    'summonerName': 'copypasteyoasobi',
#    'leaguePoints': 664,
#    'rank': 'I',
#    'wins': 104,
#    'losses': 62,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'mpR2s8kdvu4vb-acSgYt6axTNADjq_14gcsLPtYeA1S_ef4',
#    'summonerName': 'Bayonets',
#    'leaguePoints': 543,
#    'rank': 'I',
#    'wins': 252,
#    'losses': 247,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '28MIrwatTgrPqryHZ-wJdxlTeA3PFpxeBS41TvRBWJxHwl13sxVk6qtBxw',
#    'summonerName': '',
#    'leaguePoints': 545,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 124,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'sU01hO-yB56tuw0ee77jIn1NRZ0E-D3kYoth3FBBFWZbBeA',
#    'summonerName': 'Blahyay',
#    'leaguePoints': 641,
#    'rank': 'I',
#    'wins': 270,
#    'losses': 218,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'QXvKMd5OgUUBBlcZRhT6lVOaXSKCQ7dbOvToMvDelCiWfNc',
#    'summonerName': 'HarmlessPikachu',
#    'leaguePoints': 480,
#    'rank': 'I',
#    'wins': 253,
#    'losses': 224,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'UPKXjHLSTvBJP6ttKLh9aSt9UR01JkzfZramI-IxDkkSqvE',
#    'summonerName': 'LearningToPIay',
#    'leaguePoints': 649,
#    'rank': 'I',
#    'wins': 205,
#    'losses': 178,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '2h2ReqF4ilIBEbv81hsCE-V1grIS4S497FqMMLKNa6upzZHT',
#    'summonerName': 'hyoon is cute',
#    'leaguePoints': 541,
#    'rank': 'I',
#    'wins': 66,
#    'losses': 41,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'MaGJMiQCYDNS6Vlwz45jYqGphE1gZCQuKo1De3O74Pg5tWI',
#    'summonerName': 'Phoenixaa',
#    'leaguePoints': 844,
#    'rank': 'I',
#    'wins': 503,
#    'losses': 437,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'rOgtqMvwiWOmwaEHoQsox2JzlfoUHowtdNCgxf34MHR73rE',
#    'summonerName': 'Degreeº',
#    'leaguePoints': 678,
#    'rank': 'I',
#    'wins': 388,
#    'losses': 261,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '03KwZO6C0ZSGsc8KIrZkz3u3tf3-YZ43HfHWz5lOOj97hJlyXiapA3M1mA',
#    'summonerName': 'oceanair12',
#    'leaguePoints': 597,
#    'rank': 'I',
#    'wins': 310,
#    'losses': 290,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nyvnu9AuPhejTqQnCDTjKsNvsrzC-w49N8TQIukpvNkY5Uy_',
#    'summonerName': 'kennifer',
#    'leaguePoints': 703,
#    'rank': 'I',
#    'wins': 231,
#    'losses': 192,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'Erb936sn0_DWqfHdAAWvGIyZf6JiVT_8Q0R2e07EM-MySZc',
#    'summonerName': 'Love7',
#    'leaguePoints': 701,
#    'rank': 'I',
#    'wins': 85,
#    'losses': 40,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'ENPZDolCFLOXqpGmFQsY2ydNlfuo2O-fjdWqZHb06yyaLwY',
#    'summonerName': 'yung jame',
#    'leaguePoints': 640,
#    'rank': 'I',
#    'wins': 195,
#    'losses': 163,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'pslNfkyvbt9wDvSEphYUdpEp21ohzDtwdilMh3Go-DI8ZnY',
#    'summonerName': 'Big Garlic',
#    'leaguePoints': 518,
#    'rank': 'I',
#    'wins': 98,
#    'losses': 58,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'DTEP8zFzREHzpeV7-e25hh2KWmRikcALozVv9Rw3eTAJ6fR8',
#    'summonerName': 'BestSatoJP',
#    'leaguePoints': 614,
#    'rank': 'I',
#    'wins': 85,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'P2M7jw0hHBMqtMhhq8rdHBY3ZMdOkl-KoH2GxGFWp_0dvQF1Ts7AT1YL-A',
#    'summonerName': 'LoadingRune',
#    'leaguePoints': 535,
#    'rank': 'I',
#    'wins': 273,
#    'losses': 240,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'tFVQFi2XQaLi7DTEWcK2V5bI6f3owLQGjxvzwvfRllfU8Tc',
#    'summonerName': 'CHN',
#    'leaguePoints': 637,
#    'rank': 'I',
#    'wins': 333,
#    'losses': 295,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_d02p3sO0-FJ6Ix6hRAQDZ672Be6KATxfKPY_UMhpGtl2uY',
#    'summonerName': 'FFGMario',
#    'leaguePoints': 584,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Sl0Uok8IdQ73XMh4R61fcZOo0OYMPFvn5k7oshDPIbbz7nM',
#    'summonerName': 'Mr 46',
#    'leaguePoints': 713,
#    'rank': 'I',
#    'wins': 146,
#    'losses': 104,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'bCDcxoSNY59-gF_47LxFFmProV4cKB5FLo97FZOrTBlnyIGcqQDTuWuOdA',
#    'summonerName': 'kokoiuu',
#    'leaguePoints': 605,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 74,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'EilmPw1EW0eoWs34EZyM2JPjM9rps1ZcPQ9IfXJ7f3jOHjw',
#    'summonerName': 'fource',
#    'leaguePoints': 633,
#    'rank': 'I',
#    'wins': 241,
#    'losses': 196,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'dY0aJ-Y9pW2Q78g4OwQMUFUMEG4XUoW8lgsSOq26EcNlRqI',
#    'summonerName': 'iSquirtle',
#    'leaguePoints': 602,
#    'rank': 'I',
#    'wins': 360,
#    'losses': 294,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '8ALCUs6R3osiucL1VyPtfzbyagOZ3EfEwg_pzDQBdzh8MSE',
#    'summonerName': 'badben1000',
#    'leaguePoints': 519,
#    'rank': 'I',
#    'wins': 205,
#    'losses': 182,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Zf6KQy0P58YKALYWL2-pN2rvYZXqhsS4X4Lk-j2ZSrIjtGc',
#    'summonerName': 'grn bublz',
#    'leaguePoints': 523,
#    'rank': 'I',
#    'wins': 205,
#    'losses': 189,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'HiUrKe-COPLwQH7sNPnQIzmfudgj17msIBmIDifPWOeeAX8',
#    'summonerName': 'YerAWizardAhri',
#    'leaguePoints': 652,
#    'rank': 'I',
#    'wins': 386,
#    'losses': 373,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'W3uu93KxDTHjhYAGEsLlJh6zvGZjML7i-iWcVibvOv5AN5Po',
#    'summonerName': 'junglebook1',
#    'leaguePoints': 558,
#    'rank': 'I',
#    'wins': 183,
#    'losses': 155,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1VIysmIlVUB0z1NSN3kEQqVeYuDnTKwv_rLpXv4u3BKAFVNQsVGjzb1OUw',
#    'summonerName': 'soul bleed',
#    'leaguePoints': 502,
#    'rank': 'I',
#    'wins': 381,
#    'losses': 320,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'php1e3hPJQpCzErGG7bJj2R1QHy9Dz-oWvpMapMM_kfbz0Az',
#    'summonerName': 'soldier003',
#    'leaguePoints': 589,
#    'rank': 'I',
#    'wins': 214,
#    'losses': 175,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'oJrvFHB2BUU1cGmfXJrIWb4PLGQEOCSXVBqvrmpKLHSgrozf',
#    'summonerName': 'YESSS DADDY',
#    'leaguePoints': 623,
#    'rank': 'I',
#    'wins': 65,
#    'losses': 21,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'IgNYrPS6YhkkDN_twh30GONwp0cW5udJwO0c2tnc7-niExc',
#    'summonerName': 'Lixexe',
#    'leaguePoints': 706,
#    'rank': 'I',
#    'wins': 270,
#    'losses': 242,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'l6mOX_A1-PknMpi9QV8p1niw_WFPBmjLUC4vKIgtECVc',
#    'summonerName': 'Stonerule',
#    'leaguePoints': 596,
#    'rank': 'I',
#    'wins': 209,
#    'losses': 174,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'J76Ew9mSko0A-GtGLEgb7xr_KMQnn4Z5a6dVsp_87RrC2xWPXlgPR1LXpA',
#    'summonerName': 'JŠP',
#    'leaguePoints': 820,
#    'rank': 'I',
#    'wins': 297,
#    'losses': 229,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'JmUIfKvOMNyOQfS48KoN0VEu0NjFfmlzOYdddWH6Bl-vh9A',
#    'summonerName': 'Celynda',
#    'leaguePoints': 534,
#    'rank': 'I',
#    'wins': 190,
#    'losses': 158,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'n3UdDcWND6EnADwLElewBQKT14ACYVsWygoMvMQAAGJIn5E',
#    'summonerName': 'chen du xiu',
#    'leaguePoints': 598,
#    'rank': 'I',
#    'wins': 346,
#    'losses': 335,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '_pOkJMVwanIuJgSyyrAhotcHwVmLQBpHwrjJH7cut3YTDrQmjwCzRnKQog',
#    'summonerName': 'stepee4',
#    'leaguePoints': 506,
#    'rank': 'I',
#    'wins': 218,
#    'losses': 198,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'BlBH5Hv6Be2IVapVjNj-8wamGaHMa-LNkpSC2jnvK7OAzfM',
#    'summonerName': 'Andrewk1234',
#    'leaguePoints': 532,
#    'rank': 'I',
#    'wins': 271,
#    'losses': 249,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'HOQdriJItgMKkyOWgbVo6lFs-ILgE8nLW84u5onxZDr54u4',
#    'summonerName': 'ShouIdBeStudying',
#    'leaguePoints': 531,
#    'rank': 'I',
#    'wins': 224,
#    'losses': 182,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'SPGTnQS8yoMPzIpp3sWj3wg24seFr6oyfwgVRbqe2ACWHOs',
#    'summonerName': 'TheVincent',
#    'leaguePoints': 810,
#    'rank': 'I',
#    'wins': 255,
#    'losses': 194,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'beZmZc3ij_IaDGQnvxKCsjUb9-FAHj0j2FUdgM9hVJQ-3LI',
#    'summonerName': 'Isaac Netero',
#    'leaguePoints': 555,
#    'rank': 'I',
#    'wins': 248,
#    'losses': 197,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'C9YivDEoyXMTZFpw7ZJFCukJ3nZD_pgDK8j0HgZo1Xc_ndI',
#    'summonerName': '3GØ',
#    'leaguePoints': 491,
#    'rank': 'I',
#    'wins': 125,
#    'losses': 90,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'ObiZbDKjBriZhpegxTBjZ4E-EF6akoEHKWWHXeiqpkxx',
#    'summonerName': 'LoopyNess',
#    'leaguePoints': 857,
#    'rank': 'I',
#    'wins': 228,
#    'losses': 170,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'nH3oyHO-9rVbiN4XRKqOlWt0XbYfFl1v_ZOPuneG0Exqsoh5',
#    'summonerName': 'GZaga',
#    'leaguePoints': 906,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 102,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'lRksvFLTCMXD33NHe_-M_1YSXW38wbrfRYxNcU3acPeyWe8',
#    'summonerName': 'buzzyboo',
#    'leaguePoints': 842,
#    'rank': 'I',
#    'wins': 312,
#    'losses': 261,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '95j8psoWolAsFAWQ7KKwU2jek_MMvaRJqP4IfwzMsfqOuuc',
#    'summonerName': 'Souless',
#    'leaguePoints': 840,
#    'rank': 'I',
#    'wins': 315,
#    'losses': 245,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'e5DQhq8-LkapQtDCieRVlUbCbostdZxeLKlQQFbGvAVmbzN6roWKCA3HXQ',
#    'summonerName': 'morphan xoxo',
#    'leaguePoints': 643,
#    'rank': 'I',
#    'wins': 731,
#    'losses': 658,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '4hblGijNXZH-gvQfv8IU39WasCM9Cob75cte-lQZc3PX-dXQ0ySOhJUSMA',
#    'summonerName': 'ilo ilo',
#    'leaguePoints': 661,
#    'rank': 'I',
#    'wins': 437,
#    'losses': 380,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'ZdqAgzYQSoaRXLwhJ5odJtVZZrkJROTpAZzjEEpZBHEQzFY',
#    'summonerName': 'UrFatherI',
#    'leaguePoints': 545,
#    'rank': 'I',
#    'wins': 332,
#    'losses': 323,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'LObLSntrICzt0n7cR_EhgmID5Tuf3NxwgCw5F9I1XOyWS3Qe',
#    'summonerName': 'IGORblonded',
#    'leaguePoints': 534,
#    'rank': 'I',
#    'wins': 318,
#    'losses': 278,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'RfvksP3_6Gmzz1zHIowUzZgw8vftoQIiWHtl8b987zZsUtSy',
#    'summonerName': 'zonoro22',
#    'leaguePoints': 540,
#    'rank': 'I',
#    'wins': 213,
#    'losses': 173,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'GVa6BHDCee5kxhRHT7iQWOF3bpMC68BVsTQ0i-l_Mr2TuGEQ',
#    'summonerName': 'SuperSoyajin',
#    'leaguePoints': 626,
#    'rank': 'I',
#    'wins': 198,
#    'losses': 173,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'oiDMrWZqBLXTvFpNqqgNUSEuZte7dXZySm3bKMUmURMYWF4',
#    'summonerName': 'TheResets',
#    'leaguePoints': 589,
#    'rank': 'I',
#    'wins': 433,
#    'losses': 400,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'JgkvKArj0h5I9XnkmhmpO6KZV7PbNFQ0Cq5hI-xQ8NKjqv8',
#    'summonerName': 'Learning TFT',
#    'leaguePoints': 548,
#    'rank': 'I',
#    'wins': 445,
#    'losses': 424,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'CsOkHuC1_vVKvgxZSTyDiEo4t1KFWajOLxP6C9ADnydLAis',
#    'summonerName': 'QlN',
#    'leaguePoints': 558,
#    'rank': 'I',
#    'wins': 174,
#    'losses': 149,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'vQ9Y-wvH_RUdWA3Q_wLSd5WLPTEr5d4vyvAeie7D9Db2kIg',
#    'summonerName': 'LemonyMeatballs',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 510,
#    'losses': 498,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'At6_fVkhnhVkO1ccLhhbDMibHzsdncCwKzIwGGyTn8X4RAs',
#    'summonerName': 'ucdSenpai',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 301,
#    'losses': 238,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'el_bX1rAcvR7l7CW_MtvbxwPR0rlVL4Nwp5NkazAp8mjpHQ',
#    'summonerName': 'hornyhungryhippo',
#    'leaguePoints': 586,
#    'rank': 'I',
#    'wins': 182,
#    'losses': 139,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Pe4qOkyiogTt5B_6I3Ixs_CzDjDWip8rdF0cnjiCsFJ3Ug4',
#    'summonerName': 'Bastille',
#    'leaguePoints': 540,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 116,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 't3ws-3R_3imZ4brA8o03h4Eq9WKVx2Ox2NYU-KmCUT00Oo4',
#    'summonerName': 'Myrostik',
#    'leaguePoints': 535,
#    'rank': 'I',
#    'wins': 406,
#    'losses': 391,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'deq9YSXN2VCRmCjC9vG_7TX2_4G8W29fvF35kiaS_yxt95umSIRmo5A4Bw',
#    'summonerName': 'GD FEED 2712',
#    'leaguePoints': 895,
#    'rank': 'I',
#    'wins': 282,
#    'losses': 221,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FH5oX6bJV3ho8n6H8Y_cTTCxLbD98LEasMG9jFf-ieUZ4CVXcLp004FUgQ',
#    'summonerName': 'Snaplulxd',
#    'leaguePoints': 620,
#    'rank': 'I',
#    'wins': 111,
#    'losses': 76,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Fybqnp4LeJ4MGoHLgI65wzS69tC98IR0nhtWkTKZ3rEeZCg',
#    'summonerName': 'Eagłe',
#    'leaguePoints': 569,
#    'rank': 'I',
#    'wins': 285,
#    'losses': 245,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'lzuUOncuQzFVFrMTmwA2qVPK_PwW0nMaoYu1pWlP9AULA9Y',
#    'summonerName': 'Leaguemeep',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 220,
#    'losses': 190,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'YWJ9LESESTNdcFJBCnPGQQtrhjOENCATxqnpSdUt07tJ9wbL',
#    'summonerName': 'CharmsnareNA',
#    'leaguePoints': 717,
#    'rank': 'I',
#    'wins': 151,
#    'losses': 108,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'FSmE4MdScS9ysn9eEqFPkKtoKI-M6_icSIVr7ZgmOb9PmdiR',
#    'summonerName': 'ShadowBiscuits',
#    'leaguePoints': 551,
#    'rank': 'I',
#    'wins': 415,
#    'losses': 395,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'BCb4CJ8DstOag9LfKcx-0H_mKQQFFYmTIqTj5fy5HyFki5s',
#    'summonerName': 'susu QAQ',
#    'leaguePoints': 563,
#    'rank': 'I',
#    'wins': 517,
#    'losses': 496,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'XKhGbirh919Z3eeGqz10ZoUfNBn8vpeStaoPRIQEqGXs1G2n',
#    'summonerName': 'Briketh',
#    'leaguePoints': 491,
#    'rank': 'I',
#    'wins': 162,
#    'losses': 131,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'a95L3fVWbjOdyJvuhPckqLu_LI4E2UsYbx5qNe2PrCQfPK4',
#    'summonerName': 'shizuka',
#    'leaguePoints': 734,
#    'rank': 'I',
#    'wins': 252,
#    'losses': 227,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '2iEjXcuE0-fcsEE94prvGL25-qVYjDgwnQZ48mEjBXDdoYw',
#    'summonerName': 'Mandala30',
#    'leaguePoints': 605,
#    'rank': 'I',
#    'wins': 271,
#    'losses': 218,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0IWKwTjt7gu6zY2IrTCek3ot5p0KPA7rmN0-ImAndQhvotE',
#    'summonerName': 'ThrasiosTFT',
#    'leaguePoints': 848,
#    'rank': 'I',
#    'wins': 290,
#    'losses': 272,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Nn8f6lEbZH5EUeh0eNQC0JnPldbuOxXOR7-ZPDfi-ozdyGhX7fkzbdwHpQ',
#    'summonerName': 'hellokevvie',
#    'leaguePoints': 540,
#    'rank': 'I',
#    'wins': 179,
#    'losses': 148,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Di4y5kMoCiuWA2UHAPQ8YWtOKiweIAuVwZGnwJr3U5KcK9fHz2tLP90WeQ',
#    'summonerName': 'camokr',
#    'leaguePoints': 786,
#    'rank': 'I',
#    'wins': 365,
#    'losses': 303,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'uXmm2bc6P95EBpTTJpeOKh3OgVGg_CwG21Whk5vzedbSoKEN54Kj8CM4Qg',
#    'summonerName': 'STAYCGurls',
#    'leaguePoints': 539,
#    'rank': 'I',
#    'wins': 270,
#    'losses': 216,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Pmw7zAQWucaxipLLmWm-wWyKjB-PlJ9Pw_QTEu56gvdpc89yT3AMj2t8uQ',
#    'summonerName': 'sojuathome',
#    'leaguePoints': 613,
#    'rank': 'I',
#    'wins': 90,
#    'losses': 53,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'fPcxPg-oHfhIOfg5RZLCxWJVv43tnFPXSE8xK1kSm20Tg44',
#    'summonerName': 'farland1339',
#    'leaguePoints': 541,
#    'rank': 'I',
#    'wins': 190,
#    'losses': 156,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Jdi9L-jzCKXmprRg3P18cjMBTLBLvpNM1enIv5zZ494l0b0',
#    'summonerName': 'worthless pig',
#    'leaguePoints': 523,
#    'rank': 'I',
#    'wins': 261,
#    'losses': 224,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Rz9a1il_dO0R-WsfOWQCg32ZnVGu4tLgVZABthlB6BVnkWk',
#    'summonerName': 'imnotrussell',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 141,
#    'losses': 118,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Mco85H7_ZGQdJmzDEKAWN7zFA_X7n-wdDqxfb3URk8Wj2UaS7s2Yf5gV7w',
#    'summonerName': 'observered',
#    'leaguePoints': 565,
#    'rank': 'I',
#    'wins': 333,
#    'losses': 315,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'hR_oPNK6qoRE8-7nAb10I7q-r038EtYsHjqRfRMCg7-R5-w',
#    'summonerName': 'Asha Yunie',
#    'leaguePoints': 521,
#    'rank': 'I',
#    'wins': 204,
#    'losses': 165,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CS76Recpeh37CIVoM3PmvbZA6WtJTiSYjLRNDewhi2njkxo',
#    'summonerName': 'andrewzhang2000',
#    'leaguePoints': 745,
#    'rank': 'I',
#    'wins': 158,
#    'losses': 122,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'ndCeKuTYWQjFM-7xNGAJskAREELQPTqZ0t20-V6751M8dvE',
#    'summonerName': 'Yiggles',
#    'leaguePoints': 637,
#    'rank': 'I',
#    'wins': 441,
#    'losses': 422,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '4X60Ez5Z4DFIIGUIoKyNGP6RB6ajC4F7PApJtTpuXT7Jdac',
#    'summonerName': 'saiiaka',
#    'leaguePoints': 767,
#    'rank': 'I',
#    'wins': 349,
#    'losses': 307,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ml7r7UE6rF32FKMFAVap6OJG4YdnXUktva9PgXmKEkfIIEE',
#    'summonerName': 'GirthyMeatstick',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 185,
#    'losses': 134,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'WnJByZI1wjkXsC4q5Mi1sI2SegPPV2adP_FIP4OJ17cCpyvdllXuY4AD-Q',
#    'summonerName': '',
#    'leaguePoints': 578,
#    'rank': 'I',
#    'wins': 340,
#    'losses': 318,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'D2zQ_2XpEtslfz8PQn7uDGxmTCZfby1G2YEMIeEqWr_7Wlo',
#    'summonerName': 'SlenderShlong',
#    'leaguePoints': 449,
#    'rank': 'I',
#    'wins': 424,
#    'losses': 386,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Xj1XMjsHW_7wEpStqZeIBsqpByh0weXMkePQZ-0bL2Dq2jH1',
#    'summonerName': 'I Am Cute AF',
#    'leaguePoints': 695,
#    'rank': 'I',
#    'wins': 306,
#    'losses': 257,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'PLU7_2S1HRm5on4NVCBtrp_av7xgRA0zN7ks_TwgzYhucRU',
#    'summonerName': 'Jyu V Grace',
#    'leaguePoints': 587,
#    'rank': 'I',
#    'wins': 381,
#    'losses': 363,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '8Z1ex7QrhU8dun3erC8OKWOXRKH9yTfAT7QzBGiJGuZs10I',
#    'summonerName': 'GurtG',
#    'leaguePoints': 801,
#    'rank': 'I',
#    'wins': 301,
#    'losses': 239,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ZgXmPNc24Y8fOFb-sO_SvE82OPWz_vPXQNfVLYmtdPJ42Ww',
#    'summonerName': 'MajoritySC',
#    'leaguePoints': 557,
#    'rank': 'I',
#    'wins': 290,
#    'losses': 264,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '2DI_fFdwwdaBUrG9x-CWYPz1ORbIOscoxPZR0JCELyych-c',
#    'summonerName': 'Downpour',
#    'leaguePoints': 870,
#    'rank': 'I',
#    'wins': 524,
#    'losses': 537,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'doM4nSpTKP_Vevieqd9LpE6navFyDsNazFnwBGCurBDAbrU',
#    'summonerName': 'PureAdrenalin',
#    'leaguePoints': 506,
#    'rank': 'I',
#    'wins': 168,
#    'losses': 134,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'pUIvUU9qdhCNE1cCtytrodnpDCsuPrkSpirC4YUxNHzk5tIhu40vNRwJTw',
#    'summonerName': 'CrippyAC',
#    'leaguePoints': 541,
#    'rank': 'I',
#    'wins': 294,
#    'losses': 245,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'yZ9mqedLw5ZZnAirRlLjhyli600ii7mDQmFJk-sYjDpRaySA',
#    'summonerName': 'ttv NicNac19',
#    'leaguePoints': 825,
#    'rank': 'I',
#    'wins': 347,
#    'losses': 320,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'mGI71Dm0X6kVEDEOeE_XRM6aLspm1zD48c8CYhALbN5-LbrL__y8-JRScw',
#    'summonerName': 'superflamezz',
#    'leaguePoints': 550,
#    'rank': 'I',
#    'wins': 225,
#    'losses': 157,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'SMos36hNpOV44Er5YjCrSFy2KMZmI_W3qNBpZDbrxn3jwFo',
#    'summonerName': 'Itachisax',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 289,
#    'losses': 241,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'K1hMwesfhOcmFtaNsRpEPxvdNZVhCqv51tEheVN0byY7yHJUPC7Tm3PGkA',
#    'summonerName': 'zebmmm',
#    'leaguePoints': 614,
#    'rank': 'I',
#    'wins': 199,
#    'losses': 146,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'kyvD4DBw5LpusRLqSDPzK-QwzV9PIVFrEhUqiaxMoOAIx25ed_qS8Ci1ug',
#    'summonerName': 'alzys',
#    'leaguePoints': 629,
#    'rank': 'I',
#    'wins': 503,
#    'losses': 432,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'TX3btc2WtxCZVK7ajxeJ_qW_CwGZFPpLZhbVgI_E2h_WoZ4',
#    'summonerName': 'Ajolt',
#    'leaguePoints': 525,
#    'rank': 'I',
#    'wins': 375,
#    'losses': 351,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'K0rrLMFpATaGYl08PMaGgEA3FG7-BGNDzqwk0MnBSmyqYT0',
#    'summonerName': 'mutinyonthebay',
#    'leaguePoints': 464,
#    'rank': 'I',
#    'wins': 316,
#    'losses': 295,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'AIk4JmJm32SR7tupnninEQpDrHpvLEYF4r5fGlFrvXATKXZUsCCVO-Pxbg',
#    'summonerName': 'Windy Afternoon',
#    'leaguePoints': 824,
#    'rank': 'I',
#    'wins': 497,
#    'losses': 445,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bhOZBhyjPAJd8Y2VxDHclPlOMcJ3Y5ao4xjyU6Nz8iiDNzM',
#    'summonerName': 'bopster',
#    'leaguePoints': 697,
#    'rank': 'I',
#    'wins': 274,
#    'losses': 260,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'xEy3COjoLR8pA8TnLr6_aaYI1ElrVwPofApz6hswSNCKVjl4sAR_T2laoQ',
#    'summonerName': 'PancakesTFT',
#    'leaguePoints': 804,
#    'rank': 'I',
#    'wins': 177,
#    'losses': 130,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '5VyxF5yuJarNzZw9tkz7M6vgG3nmZW5lD-JWDi1X-MTtEnM',
#    'summonerName': 'Su Ku Nah',
#    'leaguePoints': 1016,
#    'rank': 'I',
#    'wins': 263,
#    'losses': 193,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'eoZHljf6f3tMV84epHkhgOB702NWOsx7AEdLZMVzZnPA4_0',
#    'summonerName': 'Leishmaniac',
#    'leaguePoints': 537,
#    'rank': 'I',
#    'wins': 285,
#    'losses': 261,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'j-4droTY_PIkrImUortajmIR3B89qZNFL3Xcct4l1k0LDDfw',
#    'summonerName': 'stevie69420',
#    'leaguePoints': 581,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 115,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '8tnFZSlJbJ8X8ZjBRA0XgX6vsm7H0LcQeYUG5oJiwlpAr1U-',
#    'summonerName': 'bmoy',
#    'leaguePoints': 677,
#    'rank': 'I',
#    'wins': 348,
#    'losses': 295,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'DpQD8ytt-40N87PJsBExUr65TqXTQ0Jbcgv7zJQlUR861Y4',
#    'summonerName': 'Rising Phoenix75',
#    'leaguePoints': 631,
#    'rank': 'I',
#    'wins': 381,
#    'losses': 290,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'YvDWwwuKPGklJI4YOzgLY7RD2W5EeA6Ul4kQLsZ5bviwQrw',
#    'summonerName': 'Mikoto Misaka',
#    'leaguePoints': 576,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 70,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '0CUQstmsIyt-3YTxBbAU91Y_1hAdKuxVFbTTmwGfQBsb5Kg',
#    'summonerName': 'Xiurén',
#    'leaguePoints': 684,
#    'rank': 'I',
#    'wins': 294,
#    'losses': 263,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '698Hvkiw2Cv1gW7ZIupRsFEsNleidHJcbYhcYytW-5ywssg',
#    'summonerName': 'Xenor',
#    'leaguePoints': 612,
#    'rank': 'I',
#    'wins': 339,
#    'losses': 304,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Ba5Gj0q8DdQEjftW1T1SdSCBajiou7QncIEUcfZYBksNiaJl-dWbArL0qQ',
#    'summonerName': 'Rinze Morino',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 164,
#    'losses': 123,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'i3fnFLCKritjoQ2ssfNs7AIWbZuDKSW5_neK-VK89OCvBRTVPo-pdyyBbA',
#    'summonerName': 'PetrifyOCE',
#    'leaguePoints': 745,
#    'rank': 'I',
#    'wins': 150,
#    'losses': 120,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'PzE2_k4OdwcCj4Jj7VuBE8cxwa2Mhbjbz7GI5j4KyL1WYnKH',
#    'summonerName': 'Kingmansteve',
#    'leaguePoints': 610,
#    'rank': 'I',
#    'wins': 248,
#    'losses': 214,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'rpqBE59aNPUQ_07eQkBDjq40ozKazSn2j80JgD4VeBZfcWMy92oElHy_hw',
#    'summonerName': '300 ping pog',
#    'leaguePoints': 557,
#    'rank': 'I',
#    'wins': 293,
#    'losses': 262,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'iZujt1U_LcbJ0YxTjxKA1J-DKQwU4Wd8dKDO_OLD9Owkxyw',
#    'summonerName': 'Tacosu',
#    'leaguePoints': 529,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 127,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'E7VkEkMRoQPyUqQlXGyWwHqH57-0xB_A2Bwltqx5X6_7XbI',
#    'summonerName': 'DameConcombre',
#    'leaguePoints': 645,
#    'rank': 'I',
#    'wins': 303,
#    'losses': 295,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'n3PH32y_iaJF2K093_3yOjNlqD-68eH6tGrV8V11F4RhUUiS',
#    'summonerName': 'Advisings',
#    'leaguePoints': 516,
#    'rank': 'I',
#    'wins': 125,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'K4j8bXM_NuCChZy4RC7RMck9__56k6iPElSFRgCRtW4Oh9WVhwbtW5tAuA',
#    'summonerName': 'bigbol',
#    'leaguePoints': 763,
#    'rank': 'I',
#    'wins': 162,
#    'losses': 137,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'u3aZwChfr7kcbJxCAfsI5fFl6avPw6CbtSLUnFMR-p001WvDqDmCs7_n3g',
#    'summonerName': 'jindofever',
#    'leaguePoints': 690,
#    'rank': 'I',
#    'wins': 370,
#    'losses': 347,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ppWd0mNzaBbVPovOyLwPOzkSDS3uOIMOus7-MEDoS3PWdnY',
#    'summonerName': 'iiLucky',
#    'leaguePoints': 789,
#    'rank': 'I',
#    'wins': 397,
#    'losses': 332,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '1-SU3GT4ESVv8gEDB86v8nKZIoxgj3LRdCCWUVMMMLpSFPk',
#    'summonerName': 'egg boy john',
#    'leaguePoints': 847,
#    'rank': 'I',
#    'wins': 410,
#    'losses': 355,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Oqb5GK0VYAPBp63qxwBvaZSDD8yQfWf9CNmJOkOtGQsMqKV-',
#    'summonerName': 'kesjp',
#    'leaguePoints': 860,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'I3DSIWuXYDEd9D95oXUbNnmQghSdOTcmt6JO_tulpG3AFQ8',
#    'summonerName': 'DocPwn',
#    'leaguePoints': 627,
#    'rank': 'I',
#    'wins': 453,
#    'losses': 434,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'mTbURWe-7bOIIYUnwtoOlL2ciwYYxZXkOQgNiIEzmrqzEkU',
#    'summonerName': 'MeisoZ',
#    'leaguePoints': 501,
#    'rank': 'I',
#    'wins': 141,
#    'losses': 117,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Kv22jMg5PjhvxV287Z5dscjJOlFhTgSmJcdoBRJPwPJpNqjjDwxUEJSHXA',
#    'summonerName': 'Rednex',
#    'leaguePoints': 902,
#    'rank': 'I',
#    'wins': 937,
#    'losses': 929,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'MBJi5g1MOPxv3k-0cG4A0R6tqqLuQGWif5e73Kowgv5bdiEKfUPz_bpHaA',
#    'summonerName': '',
#    'leaguePoints': 637,
#    'rank': 'I',
#    'wins': 85,
#    'losses': 42,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'JHrtjeeFW702VjRAMpKKJvjEPE_5Lua9D4_kfpxmJaC2Amg',
#    'summonerName': 'eggyslash',
#    'leaguePoints': 738,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'VOl6ZDS9TNiArBrRjtci1iEW7mf4N6CGMZreqDqIIMJ-QY7y',
#    'summonerName': 'ttv TFTDaiLo',
#    'leaguePoints': 554,
#    'rank': 'I',
#    'wins': 479,
#    'losses': 471,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'mSiY4FST2SwcpwE3lI1m9phReIvO2f12JqWRpJvjmZpDYslrRoOL_bYwUQ',
#    'summonerName': 'stansk',
#    'leaguePoints': 814,
#    'rank': 'I',
#    'wins': 256,
#    'losses': 221,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'rH_YVvAPm1aPrEdNQM49CEzkch1_NKhDrhgWoOu4tgMQby8',
#    'summonerName': 'Kayhan',
#    'leaguePoints': 499,
#    'rank': 'I',
#    'wins': 244,
#    'losses': 211,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'OjdA5jTnqy_b6ysaKHfbLvclKPJ66oJh06E8QxgmvSlBhIXm',
#    'summonerName': 'stonebreaker004',
#    'leaguePoints': 730,
#    'rank': 'I',
#    'wins': 283,
#    'losses': 229,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'XjnBps1C3sNVUIWIKMAwaW1iEgF7g0eAhfCygedJRzh5GJw',
#    'summonerName': 'gou bi',
#    'leaguePoints': 690,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 109,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Cuyq4hP_LHUQ35iLJEMgsyn9E49zBhrLOamdxDfkA2edAio',
#    'summonerName': 'Smites NA',
#    'leaguePoints': 674,
#    'rank': 'I',
#    'wins': 271,
#    'losses': 238,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'ML_88CKE6qQgHjOHmB4E8K0vZFQg9Sz6IdtTCi479_Tajk7qN-_S5WAMBg',
#    'summonerName': 'TFT Jaren',
#    'leaguePoints': 576,
#    'rank': 'I',
#    'wins': 282,
#    'losses': 228,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'B14apTaKiGjduieHItzob975jI39PdYGjUcGL1vVzwlpZJc',
#    'summonerName': 'Mypumpkinbaby',
#    'leaguePoints': 747,
#    'rank': 'I',
#    'wins': 182,
#    'losses': 149,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'cGODQSzvgDV_WKnBj8KqQ0VHqTuOvVNMZjZZJL4durbegwAC',
#    'summonerName': 'Deebznuts',
#    'leaguePoints': 615,
#    'rank': 'I',
#    'wins': 316,
#    'losses': 267,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bDZv51Gfo6OOncbf-AtZNkpGsZyluOh4f56KVEhiAThsfqk',
#    'summonerName': 'dinob0y2011',
#    'leaguePoints': 521,
#    'rank': 'I',
#    'wins': 281,
#    'losses': 267,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0SbraWl4nWUZxvsn8Wmz4tmjh4eT5QAldM-xOYzAUDWOk8-P',
#    'summonerName': 'Gregthunder',
#    'leaguePoints': 467,
#    'rank': 'I',
#    'wins': 170,
#    'losses': 121,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'iSw40_ORg0vrgF6dEqm1cAEMr_wqsFv2TmFNvJZ-jCXYMCk',
#    'summonerName': 'Auustin',
#    'leaguePoints': 570,
#    'rank': 'I',
#    'wins': 167,
#    'losses': 131,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'S5WFDt1PJW8H1XncNeeipZXzU9hltlupJr3iCEfpimcFmi8',
#    'summonerName': 'Yung Charmander',
#    'leaguePoints': 676,
#    'rank': 'I',
#    'wins': 468,
#    'losses': 439,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'wO7ILWvga7Y1DPJF3Kdw4gw7m0F7KPbJwDzydAQqBwnHbq9i',
#    'summonerName': 'meatcaketien',
#    'leaguePoints': 430,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 60,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'J9IkvcvYkcFEtvW5BKO-d4iLoEXrgMsN1nTSGtsgR3NTkv4',
#    'summonerName': 'Bunji',
#    'leaguePoints': 610,
#    'rank': 'I',
#    'wins': 371,
#    'losses': 320,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0YPlAImEzR0nwfwuVWqR3wFEmWj7r6qQs50W6-dCYrupDkM',
#    'summonerName': 'Army',
#    'leaguePoints': 651,
#    'rank': 'I',
#    'wins': 169,
#    'losses': 139,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'bc_cxpVbLdzJQdqvIIcLth5BkqYgBeKq9ZoTyVjKJYjaw9bV',
#    'summonerName': 'hitscanhero',
#    'leaguePoints': 675,
#    'rank': 'I',
#    'wins': 562,
#    'losses': 575,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'TnMGXKZh2fJqyCFXBp7VDRr8ob_q7nSi0HSlOeDxJW7mSqg8Fb0bVR8pBA',
#    'summonerName': 'LapplandLappland',
#    'leaguePoints': 740,
#    'rank': 'I',
#    'wins': 359,
#    'losses': 333,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'TpHceKuhKJw-T_c3hVtxNjgYieCik9Q5yCD9h6UaPWyVG2M',
#    'summonerName': 'taeyeòn',
#    'leaguePoints': 688,
#    'rank': 'I',
#    'wins': 262,
#    'losses': 246,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'NTfNny5t3ebOoTo81GYHUfWw0ys1A_xXlDHwOunkVp6utOo',
#    'summonerName': 'SuperShySuperShy',
#    'leaguePoints': 581,
#    'rank': 'I',
#    'wins': 282,
#    'losses': 271,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CnHOzEfbluT_GpDSkA_5WYCpl6ZTxyP91nrCAa1VJvNgzoc',
#    'summonerName': 'Ian952',
#    'leaguePoints': 622,
#    'rank': 'I',
#    'wins': 297,
#    'losses': 280,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'UVwthMbwGC32UZT3IApHVivl2YpaT4Mw3q0aJUvmMgLuaBS8-x_bvh6Rig',
#    'summonerName': 'Kayle fanboy',
#    'leaguePoints': 773,
#    'rank': 'I',
#    'wins': 143,
#    'losses': 94,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '79p4tLBqS2D3rGNDcHptSDbqxMXNlrIcNOdjtRHANUSz1lM',
#    'summonerName': 'eluusionist',
#    'leaguePoints': 572,
#    'rank': 'I',
#    'wins': 216,
#    'losses': 168,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'hypUAJi8GtQurf86chblhbEQAm_AvtUcV_lPPMqfWmdA0i-ZcIwVxKpoCQ',
#    'summonerName': 'VOIDS1N',
#    'leaguePoints': 850,
#    'rank': 'I',
#    'wins': 370,
#    'losses': 305,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'YOKLA5d1j0PWYMctYizj8K9nOftqrNwFwU6pddNzHEOrU-M',
#    'summonerName': 'Lab 010 Barney',
#    'leaguePoints': 713,
#    'rank': 'I',
#    'wins': 194,
#    'losses': 155,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'lcJ2F1rptNq3S5zFQKiVIEyBAehADSoRhmsnOPfoovCENoEsDEIXl_9M_Q',
#    'summonerName': 'Ttv Zeegy99',
#    'leaguePoints': 626,
#    'rank': 'I',
#    'wins': 309,
#    'losses': 285,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'sH608AQznawa1DjUqjlTN0Pwu2vMImuWESBUxkl1IRYdrZQ',
#    'summonerName': 'E2D',
#    'leaguePoints': 494,
#    'rank': 'I',
#    'wins': 184,
#    'losses': 151,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'VQTK5j9unqh3oB9VOfO6VVIdaxsDaZj6n5WXzh9nngoDex8suqk_2xVD7w',
#    'summonerName': 'soulblackRD',
#    'leaguePoints': 718,
#    'rank': 'I',
#    'wins': 142,
#    'losses': 107,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'DtRu9KndF-0VBlPCTcABUS82-C80C4EeQkM-fD9OwIZfPHw',
#    'summonerName': 'tboy PhD',
#    'leaguePoints': 837,
#    'rank': 'I',
#    'wins': 204,
#    'losses': 150,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Od1xOgYCo6MDjkwt2LXo2D23pUlgVcwvV3990aB-ZQsbNdKwTVlBKQzpSg',
#    'summonerName': 'urbuiltdifferent',
#    'leaguePoints': 619,
#    'rank': 'I',
#    'wins': 269,
#    'losses': 235,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nLfQXTKY0Fd6sHC16LS3pDhIzNxHoa6NcOptG6o7IiUuTesD',
#    'summonerName': 'chiuonthese',
#    'leaguePoints': 666,
#    'rank': 'I',
#    'wins': 249,
#    'losses': 202,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'NrVnCw38_6NoeqWetw3Vlh1qksqvIPwV-8FHPvX-RKMWPBsBpEj_pkVxVg',
#    'summonerName': 'Susamongusmoment',
#    'leaguePoints': 478,
#    'rank': 'I',
#    'wins': 480,
#    'losses': 432,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'w-Y-nmgzCRc9kQdMTBc4ontBKj7qDRYvqNbUkaUTEx5Rdgx0',
#    'summonerName': 'JiuJiu Yuumi',
#    'leaguePoints': 682,
#    'rank': 'I',
#    'wins': 262,
#    'losses': 236,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'W6YhgbT8QUnEPeL2LMosL9OGP12EBEFDAoi5ha6b1k7WMc0',
#    'summonerName': 'GameBox',
#    'leaguePoints': 575,
#    'rank': 'I',
#    'wins': 418,
#    'losses': 383,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'PLjvOBoelgSvbe8PW08Olie3zU5IaTM-bbdPzo_nnxwGgpqf',
#    'summonerName': 'Nollam',
#    'leaguePoints': 541,
#    'rank': 'I',
#    'wins': 440,
#    'losses': 384,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ySuSIAZtRnZFIibk2Cb10jHX61NadPZSKDZqme7damiCedA',
#    'summonerName': 'gyuls1',
#    'leaguePoints': 768,
#    'rank': 'I',
#    'wins': 631,
#    'losses': 586,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'RtX7CXHRROIgYdMVKMWczIgKL9VNSbEBdV2tHzuU-d2JShw',
#    'summonerName': 'go bears',
#    'leaguePoints': 626,
#    'rank': 'I',
#    'wins': 119,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jQf5dgBADAsaQBq95nOWJ5x77ouRaD4zEhF9U0NBDaXGA4x3gPwcUynQnw',
#    'summonerName': '',
#    'leaguePoints': 754,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 97,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'WfZuzE0z5NsPvjC9S0J2TYi-dGTxY-ViT5A7dDdwRg6XC5yAp4oDuBhfCg',
#    'summonerName': 'ChaewonsShiro',
#    'leaguePoints': 772,
#    'rank': 'I',
#    'wins': 275,
#    'losses': 215,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'a98FOD44pFkQ4db8Y_FHNr4FJGZYgXrhz4RzbcHdO2WkzeM',
#    'summonerName': 'XTheFarmerX',
#    'leaguePoints': 553,
#    'rank': 'I',
#    'wins': 299,
#    'losses': 244,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'WWL_WNqZymQoT2s_UXEB_Vow2UvveAapl9ty-oMNojyYKhWn',
#    'summonerName': 'hijeffers',
#    'leaguePoints': 661,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 128,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'v6Z-Po-7pwXalZrSVILjEdatY5GNkhvZlu0IQ4U3jy2TW_Q',
#    'summonerName': 'Rookey123',
#    'leaguePoints': 525,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 138,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KNlAzkvPdTFQuvSLaUrSqPVFZud6zTLMkkVE9E51dIfvCZ0',
#    'summonerName': 'daCableguy',
#    'leaguePoints': 832,
#    'rank': 'I',
#    'wins': 168,
#    'losses': 133,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'q0R-bXXjbZaREc57hadIEV3bZbVlcC5cJxayjT2inF6NvmA7KBdZ_bMbPA',
#    'summonerName': '',
#    'leaguePoints': 736,
#    'rank': 'I',
#    'wins': 99,
#    'losses': 67,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'LGMqOEurHxDylO7U1ytFuMiPAALjYM200tdu2qhhwwal57s',
#    'summonerName': '300JAX',
#    'leaguePoints': 711,
#    'rank': 'I',
#    'wins': 218,
#    'losses': 158,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
# ...
#    'hotStreak': False},
#   {'summonerId': 'qY0MO0_YEnpM7OxXkSWI5f0h0yv45U4Va33khPDGVN7TQfQ',
#    'summonerName': 'JesusTeemo',
#    'leaguePoints': 818,
#    'rank': 'I',
#    'wins': 379,
#    'losses': 346,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '3ZDrJVZJ4RAqRYOXRN3trg10ELpEyClNiYz1kIw8dGfB7EtyCUpv4oiBQg',
#    'summonerName': 'ltsAnEighth',
#    'leaguePoints': 848,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 72,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'r5OHX5mdXhk-ApxgNEWQkPOra3r5d0cumOgA5h18e6bwpqfyetAdxhj-UQ',
#    'summonerName': '',
#    'leaguePoints': 669,
#    'rank': 'I',
#    'wins': 70,
#    'losses': 33,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'UbCQ_BoL7AbX9ViTn7M1m9MyrJi2_glh0C0WYMvH6r_4TTE',
#    'summonerName': 'Mango Nibbler',
#    'leaguePoints': 611,
#    'rank': 'I',
#    'wins': 187,
#    'losses': 143,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'HGJz95YRi51HucLF0M0mizoGGTq06fGk3RorZk3IdRknulw',
#    'summonerName': 'mali uwu',
#    'leaguePoints': 509,
#    'rank': 'I',
#    'wins': 263,
#    'losses': 204,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'fcEwjk-apj9-cMxKMDOXef9w2O1fCf4JlFXgUQdbXvmC6og',
#    'summonerName': 'Tennisfrog',
#    'leaguePoints': 608,
#    'rank': 'I',
#    'wins': 246,
#    'losses': 174,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ig_WjjAvQcq9MjJ5XUNVENAUM8B5tMl6zdPBzbO6oPCJD7Zm',
#    'summonerName': 'mental is key',
#    'leaguePoints': 580,
#    'rank': 'I',
#    'wins': 260,
#    'losses': 234,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'xxW6WBvJ--SMpzJKwcGvtPe8QQrN378X0SpeGq_q1-NNynY',
#    'summonerName': 'Cilonas',
#    'leaguePoints': 505,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 68,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'uv-xi2YeCjKvRLSvXKj6kBTA80auv6IG1BHksnzciu7dufI',
#    'summonerName': 'ttvitshoodiet',
#    'leaguePoints': 735,
#    'rank': 'I',
#    'wins': 721,
#    'losses': 636,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'r84iUBjoNnb3O5-aGYsuvNFNjJX3XfBH8i8Oy7vxE-JzEZFn5V8Zdna44A',
#    'summonerName': 'waterboy34',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 174,
#    'losses': 140,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'muWuK3_S247llLr2C7KmiD8C4qej45Gzi51_qEuwC6jb_8Y',
#    'summonerName': 'Jato Wiggins',
#    'leaguePoints': 680,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 81,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Dg8g21dfmr4wgifeckYbiTm1moQ_IHczlmFJMqvsEoYPfPs',
#    'summonerName': 'misssingg',
#    'leaguePoints': 749,
#    'rank': 'I',
#    'wins': 239,
#    'losses': 237,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jFiTTKBPmApE9JJ7QZxPmiz9LXUDp9TLAKRynGtHCDyRUS4',
#    'summonerName': 'Southern',
#    'leaguePoints': 744,
#    'rank': 'I',
#    'wins': 100,
#    'losses': 48,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-Q3aymiDupaLLi1FBx18RyK58kZnTD6_v29POaHjzcf5HDlI',
#    'summonerName': 'kohada20',
#    'leaguePoints': 655,
#    'rank': 'I',
#    'wins': 143,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'spoKjJWIrRL1mj0mik3HJfbSqsQTm-8cZmp-dhZ0GNC2QgH-',
#    'summonerName': 'KingSantee',
#    'leaguePoints': 538,
#    'rank': 'I',
#    'wins': 170,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'BDQnAopFSv9iPqvr7QoS-ulf3jWbgya1XGRYNabzpNlKGnE',
#    'summonerName': 'Guario',
#    'leaguePoints': 746,
#    'rank': 'I',
#    'wins': 196,
#    'losses': 155,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'ZeBwPYYM30WNKIzjx0zLbzWnpQ9IFrh1hMRS1O7IJ86rISE',
#    'summonerName': 'xJanoh',
#    'leaguePoints': 674,
#    'rank': 'I',
#    'wins': 386,
#    'losses': 349,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'hrWT6oD8bM9b_T9j5EhD9xiSL7wqNx5h8nSsB6dugp6H7_w',
#    'summonerName': 'Kaoisa',
#    'leaguePoints': 524,
#    'rank': 'I',
#    'wins': 249,
#    'losses': 236,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'D2_wfvPZuEAvYTUlFkR0dItIp1KG76w5ptZCv8XBMfTM1Q4',
#    'summonerName': 'TropicalCrayon',
#    'leaguePoints': 799,
#    'rank': 'I',
#    'wins': 166,
#    'losses': 133,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'mp6_nfYWZg4WsKG1NrQ4KiGU4p-kTWLL4tfGUVmSte18_Zo',
#    'summonerName': 'PogiTheCorgi',
#    'leaguePoints': 545,
#    'rank': 'I',
#    'wins': 227,
#    'losses': 193,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '1fgmtPZ4V5LdFP1ppBIWm6x8yFPQLKfdyAHHtlbWryy8xKo',
#    'summonerName': 'ksid',
#    'leaguePoints': 768,
#    'rank': 'I',
#    'wins': 519,
#    'losses': 479,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3rl170Jyt3LuWEuNSGbQr8tmmTRLNqcHTd-Vu2olEUi7f6mW',
#    'summonerName': 'cornbreadredfrog',
#    'leaguePoints': 482,
#    'rank': 'I',
#    'wins': 151,
#    'losses': 111,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ayIQT5H14ylbih5chIfIe9yQC9mqEQrthm--FsLDd8bmaPw',
#    'summonerName': 'SagecR',
#    'leaguePoints': 542,
#    'rank': 'I',
#    'wins': 285,
#    'losses': 222,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3NIZW7i5uLwB77wQ69obBTC1RoDXJw8yHO_-P1Xb1hcHlmA',
#    'summonerName': 'Fujj',
#    'leaguePoints': 652,
#    'rank': 'I',
#    'wins': 369,
#    'losses': 337,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'JmsGAxezc9sEqqTSohCDuMhcFTFiYrthnc2BrNIWmpsmuBZtTRTMYupJTA',
#    'summonerName': 'NeamFromVietNam',
#    'leaguePoints': 623,
#    'rank': 'I',
#    'wins': 377,
#    'losses': 358,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'mZr14hxC396WePuOf3DPIf3gwJKXDRg9TEdx3ijKQyCxGhI',
#    'summonerName': 'msmys',
#    'leaguePoints': 897,
#    'rank': 'I',
#    'wins': 259,
#    'losses': 221,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'yZAFofWafJxHVZowUTfLO3COn0_Mpf5Mmf8_oKQK6GQnPb0',
#    'summonerName': 'Iyr',
#    'leaguePoints': 511,
#    'rank': 'I',
#    'wins': 199,
#    'losses': 167,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'pdvfJnAEdEO7Jjo1m8Nor1KDHGWEdq-UUlO8P28wkGEyAoc',
#    'summonerName': 'Tanngent',
#    'leaguePoints': 626,
#    'rank': 'I',
#    'wins': 215,
#    'losses': 157,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1VIU9_FliYIx1GTFbyYjaWW3SzNVGXA4v55f1oDcIf91ew4',
#    'summonerName': 'Asianhops',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 538,
#    'losses': 528,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KpW-k3nWkMBowKAWZxBSfJwPsquZAkGa32mf-Fm2xQTTgW0',
#    'summonerName': 'Riot Hubris',
#    'leaguePoints': 502,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'Wouhg7wtMh6M7Tyz9jmLFUvdgOKIeZh_c01whKIyKXzHkvdf',
#    'summonerName': 'Achiever',
#    'leaguePoints': 643,
#    'rank': 'I',
#    'wins': 510,
#    'losses': 438,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'za_N-lULqgu4Enui5BtECxCZeutND58bvQTKbGiruGzTqTrr',
#    'summonerName': 'Taengoo4EVA',
#    'leaguePoints': 637,
#    'rank': 'I',
#    'wins': 329,
#    'losses': 276,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ylaps19fLjAYDPce38t6am8iCHl0HgFPd_znN6d34pl7uTw',
#    'summonerName': 'Fundamental',
#    'leaguePoints': 495,
#    'rank': 'I',
#    'wins': 318,
#    'losses': 278,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'GVKwjbUfODUlssrR4LIbMvCGy9YhspLXgdMgbldusV8pjbE',
#    'summonerName': 'RNG Lil UZI',
#    'leaguePoints': 572,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 146,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'eR41ys06vPDffuDEiYRnha3YW1EeAQ6OEms6hpuFgQnKsVI',
#    'summonerName': 'GeneralCai',
#    'leaguePoints': 698,
#    'rank': 'I',
#    'wins': 231,
#    'losses': 172,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'Pv4jM4UpfzbelKRPhIXPshGErHrK4RAqIBNA5pKgj3ePllti',
#    'summonerName': 'pannyandrew',
#    'leaguePoints': 618,
#    'rank': 'I',
#    'wins': 346,
#    'losses': 301,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'qCxkRjTzhWrS_jFdCzf9yNGGu15gC20QaiunOPtpMfXgEuI',
#    'summonerName': 'Honkerino',
#    'leaguePoints': 699,
#    'rank': 'I',
#    'wins': 152,
#    'losses': 96,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'NCcPrSldMhghFnaRVqQ7HBcsUG7FuATMD6pO9560PI3e2HQ',
#    'summonerName': 'Lazng',
#    'leaguePoints': 536,
#    'rank': 'I',
#    'wins': 148,
#    'losses': 113,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jQBbysHEv6AEmYlS5Jzz8jcWjCLmy6X7tH3lGQDlxH571HM',
#    'summonerName': 'welp3',
#    'leaguePoints': 524,
#    'rank': 'I',
#    'wins': 236,
#    'losses': 195,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'z26YzQ1EIoJBkuNEjSVvlL5wOrKB6Ij9GzrLkq0EbqtOrLbnDesJgGqGQA',
#    'summonerName': 'WalmartWorker69',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 220,
#    'losses': 151,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Sp4jaC8gO5z18tqlHkfxWA-85CtvMRU6X-9L95EOebxJaHbb4tmi2WfOlQ',
#    'summonerName': 'TTV adrxntft',
#    'leaguePoints': 487,
#    'rank': 'I',
#    'wins': 462,
#    'losses': 443,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '9HWS2nXlHsh5EtOl2YYuThg6PYEOss_D5NocsRw9o3Os8BI',
#    'summonerName': 'mäven',
#    'leaguePoints': 837,
#    'rank': 'I',
#    'wins': 218,
#    'losses': 157,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'utPqwM2sFqTR5qSHSsrwoloWhKk-NGyhvwBEedO_uAksepc',
#    'summonerName': 'Bcraz',
#    'leaguePoints': 638,
#    'rank': 'I',
#    'wins': 505,
#    'losses': 484,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'xjHO8591IdrBBS7_oKAAOVfn8fXE94fvIPDXBbOI9v8O9OY',
#    'summonerName': 'NoMoreLoveinLA',
#    'leaguePoints': 677,
#    'rank': 'I',
#    'wins': 187,
#    'losses': 120,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '416pH1DUXiuoDDPUcU10g5JoxdDCL4lbo06DHdvqTGBfOg8',
#    'summonerName': 'Dowsie Protector',
#    'leaguePoints': 520,
#    'rank': 'I',
#    'wins': 451,
#    'losses': 414,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'aHoAKpPSvDneE8yrOlm0FFtfu8_srpSLOdQLUJ9haLLeOw4',
#    'summonerName': 'Prèdator',
#    'leaguePoints': 600,
#    'rank': 'I',
#    'wins': 209,
#    'losses': 168,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'rl9Ovcf4AZMeOlQO_s9gvaJIWf3i6oQDeQsfBg_m9_T2X1I',
#    'summonerName': 'Czk',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 348,
#    'losses': 352,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'a-g7VhFUBzhkGM-iByaFEOwMBrPqtgQBFYVZN9gxf1I-6f9m2HbHETwbQQ',
#    'summonerName': 'pqwerqwer',
#    'leaguePoints': 665,
#    'rank': 'I',
#    'wins': 119,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'iwbdVpYsE6wX18z1PqyA_-M7JQA-VbhLTU6eOUEnzC_4_7A',
#    'summonerName': 'Jay',
#    'leaguePoints': 507,
#    'rank': 'I',
#    'wins': 233,
#    'losses': 195,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'AjSStUgZ6ZrtTnvN1yWxJ7SuSGfthO_K8Zi-RevDKlBKydY',
#    'summonerName': 'Pianryl',
#    'leaguePoints': 697,
#    'rank': 'I',
#    'wins': 290,
#    'losses': 243,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'slpdy_6o9fe1qARYP4RxZ_4F8qDAAOZOzh-KV5xFRapMv70',
#    'summonerName': 'help handler one',
#    'leaguePoints': 599,
#    'rank': 'I',
#    'wins': 337,
#    'losses': 316,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'GuQ2BVqv5xgHW-2FUGg_0rZb3BRYYLXhkn2f3ddHLt_wJWA',
#    'summonerName': 'Ganper',
#    'leaguePoints': 702,
#    'rank': 'I',
#    'wins': 244,
#    'losses': 185,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'I5zIr9lvn4RqpfmCLn17HM-9Pz3TGYpE4oqOENKaGkZpVKA',
#    'summonerName': 'ccasely',
#    'leaguePoints': 525,
#    'rank': 'I',
#    'wins': 435,
#    'losses': 415,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'cAZ-nNi4D5_j1yUrldcuHenjZqtTOmTxErj594A6sbQTrhY',
#    'summonerName': 'Seigs',
#    'leaguePoints': 760,
#    'rank': 'I',
#    'wins': 363,
#    'losses': 328,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'YwKPto7tnPLTLU1RqTuwrRteIrvPtbQ7jfbcN9fyz24heCXW',
#    'summonerName': 'Yaritza',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 149,
#    'losses': 117,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_PKLN6xiQMUNa49ki4-DqkugrmJ84iBatz47Z-GG3JkOCsbKImTkk4m4DA',
#    'summonerName': 'mindoI',
#    'leaguePoints': 757,
#    'rank': 'I',
#    'wins': 317,
#    'losses': 281,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'NMwhG22heMGvCfcYdj2ugofZu1T72ubjtjoJcl31rSuJTsA',
#    'summonerName': 'BananaShack',
#    'leaguePoints': 540,
#    'rank': 'I',
#    'wins': 394,
#    'losses': 358,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'lJWjMTXRnAwGuvNWdiOu-X5a02J1BvjnaHB7uuYucKhe7D4',
#    'summonerName': 'nickcaponee',
#    'leaguePoints': 597,
#    'rank': 'I',
#    'wins': 304,
#    'losses': 237,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'LS64gTUfgISmtodsBz-cSjW1BlPub5iO41eRO6P_OGnXyTw',
#    'summonerName': 'TheLargestone',
#    'leaguePoints': 675,
#    'rank': 'I',
#    'wins': 472,
#    'losses': 434,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'HW59bkChIw-h84IIaDZwxFGuAgJzJ-1y2ABvAdJhuPw-eQNum1Tu6cvxXw',
#    'summonerName': 'amariyoooo',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 221,
#    'losses': 204,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False}]}
